# %% [markdown]
# # دور ۲ (ب) — پیگیری سطح فرد
#
# پاسخ به Q8 تا Q11. همین بند دو نقص داده را کشف کرد (ردیف ۲۷ decision_log).
#
# > **لایه‌ی روایت.** منطق تحلیلی در `src/eda_lib/runners/` است، نه اینجا — طبق قاعده‌ی
# > `AGENTS.md` («`notebooks/` = روایت، `src/` = حقیقت»). این نوت‌بوک همان کد را اجرا
# > می‌کند تا خروجی قابل‌مرور باشد؛ برای اجرای دسته‌ای، ماژول را مستقیم صدا بزنید:
# > ```
# > python -m src.eda_lib.runners.r2b_individual_followups
# > ```
#
# **داده:** `dataset_v2.csv` (تجمیعی) و `person_*_v3.csv` (فردی) — نسخه‌های v1 باطل‌اند.

# %%
import sys
sys.path.insert(0, '..')

from src.eda_lib.runners.r2b_individual_followups import main

# %% [markdown]
# ## اجرای کامل بند

# %%
main()
